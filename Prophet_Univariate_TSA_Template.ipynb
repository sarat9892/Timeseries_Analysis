# %%
# %config Completer.use_jedi = False

# %%
import warnings
import itertools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.vector_ar.var_model import VAR
from statsmodels.tsa.statespace.varmax import VARMAX

import statsmodels.api as sm

import fbprophet
import prophet

from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

# %% [markdown]
# ### Load Data

# %%
perthTemp = pd.read_csv("data\\PerthTemperatures.csv")

# %% [markdown]
# ### Check NULLs

# %%
perthTemp.isnull().sum()
# Out:
# Year                               1
# Month                              1
# Day                                1
# Minimum temperature (Degree C)    76
# Maximum temperature (Degree C)    31
# Rainfall amount (millimetres)      0
# Quality                           31
# dtype: int64

# %% [markdown]
# ### Handle NULLs

# %%
perthTemp.fillna(method='bfill', inplace=True)

# %%
perthTemp.isnull().sum()
# Out:
# Year                              1
# Month                             1
# Day                               1
# Minimum temperature (Degree C)    0
# Maximum temperature (Degree C)    1
# Rainfall amount (millimetres)     0
# Quality                           1
# dtype: int64

# %%
perthTemp.drop(perthTemp.tail(1).index[0], inplace=True)

# %%
perthTemp.isnull().sum()
# Out:
# Year                              0
# Month                             0
# Day                               0
# Minimum temperature (Degree C)    0
# Maximum temperature (Degree C)    0
# Rainfall amount (millimetres)     0
# Quality                           0
# dtype: int64

# %% [markdown]
# ### Handle dates

# %%
perthTemp.drop(columns=['Quality'], inplace=True)
perthTemp
# Out:
#          Year  Month   Day  Minimum temperature (Degree C)  \
# 0      1944.0    6.0   3.0                            11.0
# 1      1944.0    6.0   4.0                            12.2
# 2      1944.0    6.0   5.0                            12.0
# 3      1944.0    6.0   6.0                             7.4
# 4      1944.0    6.0   7.0                             5.9
# ...       ...    ...   ...                             ...
# 27641  2020.0    2.0   6.0                            21.0
# 27642  2020.0    2.0   7.0                            20.7
# 27643  2020.0    2.0   8.0                            19.6
# 27644  2020.0    2.0   9.0                            14.1
# 27645  2020.0    2.0  10.0                            15.2
#
#        Maximum temperature (Degree C)  Rainfall amount (millimetres)
# 0                                22.3                            0.0
# 1                                23.4                            0.0
# 2                                20.3                            2.0
# 3                                18.7                            3.3
# 4                                21.3                            0.3
# ...                               ...                            ...
# 27641                            32.6                            0.0
# 27642                            30.6                            0.0
# 27643                            28.2                            0.0
# 27644                            29.8                            0.0
# 27645                            33.0                            0.0
#
# [27646 rows x 6 columns]

# %%
perthTemp = perthTemp.astype({'Year': int, 'Month': int, 'Day': int})
perthTemp = perthTemp.astype({'Year': str, 'Month': str, 'Day': str})

# %%
perthTemp['Date'] = perthTemp[['Year','Month','Day']].agg('-'.join, axis = 1)

# %%
perthTemp.drop(columns=['Year', 'Month', 'Day'], inplace=True)

# %%
perthTemp['Date'] = pd.to_datetime(perthTemp['Date'])

# %%
perthTemp.dtypes
# Out:
# Minimum temperature (Degree C)           float64
# Maximum temperature (Degree C)           float64
# Rainfall amount (millimetres)            float64
# Date                              datetime64[ns]
# dtype: object

# %% [markdown]
# ### Set date as index

# %%
perthTemp = perthTemp.set_index('Date')

# %% [markdown]
# ### Train Test Split

# %%
perthTemp_Train = perthTemp[:'2010-12-31']

perthTemp_Test = perthTemp['2011-01-01':]

# %%
perthTempMS = perthTemp.resample('MS').mean()

# %%
perthTempMS_Train = perthTempMS[:799]

perthTempMS_Test = perthTempMS[799:]

# %% [markdown]
# ### Datasets

# %%
perthTempMS_Train.tail(50)
# Out:
#             Minimum temperature (Degree C)  Maximum temperature (Degree C)  \
# Date
# 2006-11-01                       14.633333                       28.143333
# 2006-12-01                       15.703226                       31.529032
# 2007-01-01                       15.209677                       30.396774
# 2007-02-01                       16.425000                       31.435714
# 2007-03-01                       15.458065                       30.912903
# 2007-04-01                       11.256667                       25.693333
# 2007-05-01                       10.070968                       21.241935
# 2007-06-01                        9.000000                       19.860000
# 2007-07-01                       10.122581                       19.661290
# 2007-08-01                        8.700000                       19.319355
# 2007-09-01                        9.006667                       20.403333
# 2007-10-01                        9.819355                       23.177419
# 2007-11-01                       13.690000                       29.046667
# 2007-12-01                       14.325806                       28.380645
# 2008-01-01                       18.790323                       33.780645
# 2008-02-01                       19.103448                       32.734483
# 2008-03-01                       16.138710                       30.025806
# 2008-04-01                       12.126667                       24.323333
# 2008-05-01                       10.474194                       22.716129
# 2008-06-01                        8.883333                       19.733333
# 2008-07-01                        7.435484                       17.896774
# 2008-08-01                        6.745161                       19.354839
# 2008-09-01                        9.226667                       20.466667
# 2008-10-01                       11.177419                       24.090323
# 2008-11-01                       11.993333                       23.940000
# 2008-12-01                       14.596774                       28.645161
# 2009-01-01                       18.470968                       33.645161
# 2009-02-01                       17.614286                       32.471429
# 2009-03-01                       14.316129                       29.467742
# 2009-04-01                       13.513333                       28.063333
# 2009-05-01                       10.654839                       24.329032
# 2009-06-01                        8.850000                       19.066667
# 2009-07-01                        7.461290                       17.964516
# 2009-08-01                        8.670968                       19.145161
# 2009-09-01                        9.130000                       18.730000
# 2009-10-01                       10.958065                       24.154839
# 2009-11-01                       12.766667                       27.366667
# 2009-12-01                       15.438710                       32.000000
# 2010-01-01                       18.835484                       35.048387
# 2010-02-01                       18.032143                       33.050000
# 2010-03-01                       17.377419                       31.125806
# 2010-04-01                       13.010000                       25.710000
# 2010-05-01                        8.303226                       22.225806
# 2010-06-01                        7.410000                       19.313333
# 2010-07-01                        5.832258                       18.309677
# 2010-08-01                        5.980645                       19.454839
# 2010-09-01                        8.016667                       22.140000
# 2010-10-01                        9.703226                       25.129032
# 2010-11-01                       14.290000                       30.260000
# 2010-12-01                       15.770968                       30.483871
#
#             Rainfall amount (millimetres)
# Date
# 2006-11-01                       0.640000
# 2006-12-01                       0.122581
# 2007-01-01                       0.651613
# 2007-02-01                       0.100000
# 2007-03-01                       0.174194
# 2007-04-01                       2.353333
# 2007-05-01                       2.212903
# 2007-06-01                       1.780000
# 2007-07-01                       6.238710
# 2007-08-01                       3.645161
# 2007-09-01                       3.240000
# 2007-10-01                       1.503226
# 2007-11-01                       0.173333
# 2007-12-01                       0.522581
# 2008-01-01                       0.000000
# 2008-02-01                       1.365517
# 2008-03-01                       0.522581
# 2008-04-01                       4.500000
# 2008-05-01                       1.929032
# 2008-06-01                       5.666667
# 2008-07-01                       6.890323
# 2008-08-01                       0.612903
# 2008-09-01                       2.226667
# 2008-10-01                       1.090323
# 2008-11-01                       2.300000
# 2008-12-01                       0.174194
# 2009-01-01                       0.406452
# 2009-02-01                       0.192857
# 2009-03-01                       0.193548
# 2009-04-01                       0.226667
# 2009-05-01                       1.600000
# 2009-06-01                       4.380000
# 2009-07-01                       4.690323
# 2009-08-01                       4.161290
# 2009-09-01                       3.106667
# 2009-10-01                       0.129032
# 2009-11-01                       1.080000
# 2009-12-01                       0.000000
# 2010-01-01                       0.000000
# 2010-02-01                       0.000000
# 2010-03-01                       1.393548
# 2010-04-01                       0.773333
# 2010-05-01                       2.858065
# 2010-06-01                       1.573333
# 2010-07-01                       4.664516
# 2010-08-01                       1.935484
# 2010-09-01                       0.926667
# 2010-10-01                       0.812903
# 2010-11-01                       0.253333
# 2010-12-01                       0.516129

# %%
perthTempMS_Test.head(50)
# Out:
#             Minimum temperature (Degree C)  Maximum temperature (Degree C)  \
# Date
# 2011-01-01                       18.967742                       33.700000
# 2011-02-01                       20.817857                       34.914286
# 2011-03-01                       18.490323                       32.754839
# 2011-04-01                       14.203333                       27.936667
# 2011-05-01                       10.958065                       23.587097
# 2011-06-01                        9.950000                       19.676667
# 2011-07-01                        8.554839                       18.387097
# 2011-08-01                        8.819355                       20.154839
# 2011-09-01                        8.903333                       20.483333
# 2011-10-01                       12.232258                       24.400000
# 2011-11-01                       14.086667                       26.140000
# 2011-12-01                       17.480645                       30.593548
# 2012-01-01                       19.674194                       33.409677
# 2012-02-01                       18.341379                       31.282759
# 2012-03-01                       15.564516                       31.570968
# 2012-04-01                       14.046667                       26.406667
# 2012-05-01                       10.187097                       23.038710
# 2012-06-01                       10.086667                       19.303333
# 2012-07-01                        5.622581                       19.161290
# 2012-08-01                        8.248387                       19.958065
# 2012-09-01                        8.833333                       21.443333
# 2012-10-01                       11.680645                       24.935484
# 2012-11-01                       12.706667                       26.060000
# 2012-12-01                       16.796774                       31.435484
# 2013-01-01                       18.500000                       32.325806
# 2013-02-01                       18.635714                       34.646429
# 2013-03-01                       15.245161                       28.377419
# 2013-04-01                       16.123333                       28.690000
# 2013-05-01                       10.587097                       21.654839
# 2013-06-01                        7.820000                       19.860000
# 2013-07-01                        6.635484                       18.703226
# 2013-08-01                        9.909677                       20.254839
# 2013-09-01                       10.630000                       20.053333
# 2013-10-01                       11.338710                       24.138710
# 2013-11-01                       15.133333                       29.496667
# 2013-12-01                       15.525806                       31.138710
# 2014-01-01                       17.841935                       32.925806
# 2014-02-01                       18.157143                       33.717857
# 2014-03-01                       17.080645                       30.770968
# 2014-04-01                       13.143333                       26.936667
# 2014-05-01                       11.790323                       21.303226
# 2014-06-01                        7.506667                       19.596667
# 2014-07-01                        8.538710                       18.383871
# 2014-08-01                       10.229032                       21.535484
# 2014-09-01                       10.583333                       22.086667
# 2014-10-01                       11.445161                       24.851613
# 2014-11-01                       12.476667                       26.416667
# 2014-12-01                       14.877419                       29.674194
# 2015-01-01                       17.706452                       33.816129
# 2015-02-01                       18.628571                       33.128571
#
#             Rainfall amount (millimetres)
# Date
# 2011-01-01                       1.393548
# 2011-02-01                       0.014286
# 2011-03-01                       0.000000
# 2011-04-01                       0.873333
# 2011-05-01                       1.890323
# 2011-06-01                       4.773333
# 2011-07-01                       5.309677
# 2011-08-01                       4.122581
# 2011-09-01                       3.413333
# 2011-10-01                       2.045161
# 2011-11-01                       1.286667
# 2011-12-01                       2.174194
# 2012-01-01                       0.883871
# 2012-02-01                       0.655172
# 2012-03-01                       0.000000
# 2012-04-01                       1.773333
# 2012-05-01                       1.283871
# 2012-06-01                       4.480000
# 2012-07-01                       0.987097
# 2012-08-01                       3.800000
# 2012-09-01                       3.460000
# 2012-10-01                       0.445161
# 2012-11-01                       2.826667
# 2012-12-01                       0.800000
# 2013-01-01                       0.264516
# 2013-02-01                       0.035714
# 2013-03-01                       1.941935
# 2013-04-01                       0.260000
# 2013-05-01                       3.619355
# 2013-06-01                       0.766667
# 2013-07-01                       3.845161
# 2013-08-01                       5.180645
# 2013-09-01                       5.746667
# 2013-10-01                       1.045161
# 2013-11-01                       0.206667
# 2013-12-01                       0.025806
# 2014-01-01                       0.012903
# 2014-02-01                       0.000000
# 2014-03-01                       0.141935
# 2014-04-01                       0.620000
# 2014-05-01                       4.038710
# 2014-06-01                       3.073333
# 2014-07-01                       4.490323
# 2014-08-01                       3.535484
# 2014-09-01                       2.340000
# 2014-10-01                       1.103226
# 2014-11-01                       0.886667
# 2014-12-01                       0.006452
# 2015-01-01                       0.012903
# 2015-02-01                       1.014286

# %% [markdown]
# ### Visualize

# %%
plt.figure(figsize=(15,15))
plt.plot(perthTempMS_Train)
plt.show()

# %%
plt.figure(figsize=(15,15))

plt.subplot(3, 1, 1)
plt.title('Min Temp')
plt.plot(perthTempMS_Train['Minimum temperature (Degree C)'])

plt.subplot(3, 1, 2)
plt.title('Max Temp')
plt.plot(perthTempMS_Train['Maximum temperature (Degree C)'])

plt.subplot(3, 1, 3)
plt.title('Rainfall')
plt.plot(perthTempMS_Train['Rainfall amount (millimetres)'])


plt.show()

# %% [markdown]
# ### Forecasting with Prophet

# %%
perthMinTemp = perthTempMS_Train[['Minimum temperature (Degree C)']].reset_index().rename(columns={'Date':'ds',
                                                                                    'Minimum temperature (Degree C)':'y'})

# %%
perthMaxTemp = perthTempMS_Train[['Maximum temperature (Degree C)']].reset_index().rename(columns={'Date':'ds',
                                                                                    'Maximum temperature (Degree C)':'y'})

# %%
perthRainfall = perthTempMS_Train[['Rainfall amount (millimetres)']].reset_index().rename(columns={'Date':'ds',
                                                                                    'Rainfall amount (millimetres)':'y'})

# %% [markdown]
# ### Model

# %%
prophet_perthMinTemp = fbprophet.Prophet()
prophet_perthMaxTemp = fbprophet.Prophet()
prophet_perthRainfall = fbprophet.Prophet()

# %%
prophet_perthMinTemp.fit(perthMinTemp)
prophet_perthMaxTemp.fit(perthMaxTemp)
prophet_perthRainfall.fit(perthRainfall)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# ### Forecast Dates

# %%
forecastDates = pd.DataFrame(perthTempMS_Test.index).rename(columns={'Date':'ds'})

# %% [markdown]
# ### Forecast

# %%
forecast_minTemp = prophet_perthMinTemp.predict(forecastDates)
forecast_maxTemp = prophet_perthMaxTemp.predict(forecastDates)
forecast_rainfall = prophet_perthRainfall.predict(forecastDates)

# %%
forecast_minTemp_1 = forecast_minTemp[['ds', 'yhat']]
forecast_maxTemp_1 = forecast_maxTemp[['ds', 'yhat']]
forecast_rainfall_1 = forecast_rainfall[['ds', 'yhat']]

# %%
minTemp_Values = pd.concat([perthTempMS_Test[['Minimum temperature (Degree C)']],
           forecast_minTemp_1.set_index('ds')], axis = 1).rename(columns = {'Minimum temperature (Degree C)':'actual'})

# %%
maxTemp_Values = pd.concat([perthTempMS_Test[['Maximum temperature (Degree C)']],
           forecast_maxTemp_1.set_index('ds')], axis = 1).rename(columns = {'Maximum temperature (Degree C)':'actual'})

# %%
rainfall_Values = pd.concat([perthTempMS_Test[['Rainfall amount (millimetres)']],
           forecast_rainfall_1.set_index('ds')], axis = 1).rename(columns = {'Rainfall amount (millimetres)':'actual'})

# %% [markdown]
# ### Plot

# %%
minTemp_Values.plot(figsize=(15,10))

plt.show()

# %%
maxTemp_Values.plot(figsize=(15,10))

plt.show()

# %%
rainfall_Values.plot(figsize=(15,10))

plt.show()

# %% [markdown]
# ### Evaluate

# %%
mae = mean_absolute_error(minTemp_Values['actual'], minTemp_Values['yhat'])
print('MAE: %.3f' % mae)

mape = mean_absolute_percentage_error(minTemp_Values['actual'], minTemp_Values['yhat'])
print('MAPE: %.3f' % mape)
# Out:
# MAE: 1.274
# MAPE: 0.103

# %%
mae = mean_absolute_error(maxTemp_Values['actual'], maxTemp_Values['yhat'])
print('MAE: %.3f' % mae)

mape = mean_absolute_percentage_error(maxTemp_Values['actual'], maxTemp_Values['yhat'])
print('MAPE: %.3f' % mape)
# Out:
# MAE: 1.064
# MAPE: 0.042

# %%
mae = mean_absolute_error(rainfall_Values['actual'], rainfall_Values['yhat'])
print('MAE: %.3f' % mae)

mape = mean_absolute_percentage_error(rainfall_Values['actual'], rainfall_Values['yhat'])
print('MAPE: %.3f' % mape)
# Out:
# MAE: 0.835
# MAPE: 78458750515127.125
